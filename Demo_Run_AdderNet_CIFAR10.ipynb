# %%
import resnet20
import adder
import main
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# %run main
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train - Epoch 1, Batch: 1, Loss: 2.588328
# Test Avg. Loss: 0.032920, Accuracy: 0.178400
# Train - Epoch 2, Batch: 1, Loss: 1.501335
# Test Avg. Loss: 0.039373, Accuracy: 0.119100
# Train - Epoch 3, Batch: 1, Loss: 1.262329
# Test Avg. Loss: 0.055608, Accuracy: 0.158400
# Train - Epoch 4, Batch: 1, Loss: 1.113324
# Test Avg. Loss: 0.046094, Accuracy: 0.144100
# Train - Epoch 5, Batch: 1, Loss: 1.007577
# Test Avg. Loss: 0.040365, Accuracy: 0.164900
# Train - Epoch 6, Batch: 1, Loss: 0.813249
# Test Avg. Loss: 0.046168, Accuracy: 0.151100
# Train - Epoch 7, Batch: 1, Loss: 0.707688
# Test Avg. Loss: 0.028391, Accuracy: 0.215000
# Train - Epoch 8, Batch: 1, Loss: 0.640780
# Test Avg. Loss: 0.038402, Accuracy: 0.181100
# Train - Epoch 9, Batch: 1, Loss: 0.598305
# Test Avg. Loss: 0.044203, Accuracy: 0.166300
# Train - Epoch 10, Batch: 1, Loss: 0.694154
# Test Avg. Loss: 0.039398, Accuracy: 0.178600
# ...

# %%
# %run test.py --dataset cifar10 --model_dir '/home/mohamad.kassab/Desktop/ResNet20-AdderNet.pth' --data_dir '/home/mohamad.kassab/Desktop/AdderNet'
# Out:
#  * Acc@1 92.969 Acc@5 99.219
#  * Acc@1 92.383 Acc@5 99.219
#  * Acc@1 92.578 Acc@5 99.349
#  * Acc@1 91.699 Acc@5 99.316
#  * Acc@1 92.188 Acc@5 99.375
#  * Acc@1 92.513 Acc@5 99.479
#  * Acc@1 92.411 Acc@5 99.442
#  * Acc@1 92.188 Acc@5 99.414
#  * Acc@1 92.057 Acc@5 99.392
#  * Acc@1 92.148 Acc@5 99.375
#  * Acc@1 92.045 Acc@5 99.396
#  * Acc@1 91.960 Acc@5 99.316
#  * Acc@1 91.767 Acc@5 99.339
#  * Acc@1 91.853 Acc@5 99.358
#  * Acc@1 91.771 Acc@5 99.349
#  * Acc@1 91.895 Acc@5 99.365
#  * Acc@1 91.912 Acc@5 99.403
#  * Acc@1 91.797 Acc@5 99.414
#  * Acc@1 91.817 Acc@5 99.404
#  * Acc@1 91.816 Acc@5 99.414
#  * Acc@1 91.834 Acc@5 99.405
#  * Acc@1 91.797 Acc@5 99.396
#  * Acc@1 91.695 Acc@5 99.389
#  * Acc@1 91.748 Acc@5 99.414
#  * Acc@1 91.828 Acc@5 99.422
#  * Acc@1 91.827 Acc@5 99.444
#  * Acc@1 91.884 Acc@5 99.436
#  * Acc@1 91.839 Acc@5 99.442
#  * Acc@1 91.918 Acc@5 99.461
#  * Acc@1 91.914 Acc@5 99.440
#  * Acc@1 91.898 Acc@5 99.458
#  * Acc@1 91.870 Acc@5 99.475
# ...
